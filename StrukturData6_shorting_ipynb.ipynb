# %% [markdown]
# <a href="https://colab.research.google.com/github/meiladewin/Praktikum-Struktur-Data/blob/main/StrukturData6_shorting_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Implementasi Bubble Sort

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        for j in range(n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

# Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = bubble_sort(data.copy())  # Menggunakan copy agar data asli tidak berubah
print("Data sebelum sorting:", data)
print("Data setelah Bubble Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Bubble Sort: [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# Implementasi Selection Sort

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = selection_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Selection Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Selection Sort: [11, 12, 22, 25, 64]

# %% [markdown]
#  Implementasi Insertion Sort

# %%
def insertion_sort(arr):
    n = len(arr)
    for i in range(1, n):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return arr

# Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = insertion_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Insertion Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Insertion Sort: [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# Implementasi Merge Sort

# %%
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left_half = arr[:mid]
        right_half = arr[mid:]

        merge_sort(left_half)
        merge_sort(right_half)

        i = j = k = 0
        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1

        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1
    return arr

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = merge_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Merge Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Merge Sort: [11, 12, 22, 25, 64]

# %% [markdown]
# Implementasi Quick Sort

# %%
def quick_sort(arr):
    if len(arr) <= 1:
        return arr

    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]

    return quick_sort(left) + middle + quick_sort(right)

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = quick_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Quick Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Quick Sort: [11, 12, 22, 25, 64]

# %% [markdown]
# Tugas

# %%
#TUGAS
# Data lagu (judul, rating)
lagu = [
    ("Champagne Supernova'Oasis'", 8.5),
    ("Enter Sandman'Metallica'", 8.8),
    ("Sally Cinnamon 'The Stone Roses'", 9.5),
    ("Last Night On Earth 'Green Day'", 8.4),
    ("Painkiller 'Judas Priest'", 7.8),
    ("A Sorrowful Reunion 'Reality Club'", 8.7),
    ("Thinking About You 'Radiohead'", 5.1),
    ("Malibu Nights 'LANY'", 7.0),
    ("Shunsine 'The Panturas'", 1.0)
]

# Insertion Sort
for i in range(1, len(lagu)):
    key = lagu[i]
    j = i - 1

    while j >= 0 and lagu[j][1] < key[1]:
        lagu[j + 1] = lagu[j]
        j -= 1

    lagu[j + 1] = key

# Output hasil
print("Daftar Lagu Berdasarkan Rating Tertinggi:")
print("                -------                    ")
for lagu in lagu:
    print(f"{lagu[0]:35} | {lagu[1]:.1f}")
# Out:
# Daftar Lagu Berdasarkan Rating Tertinggi:
#                 -------
# Sally Cinnamon 'The Stone Roses'    | 9.5
# Enter Sandman'Metallica'            | 8.8
# A Sorrowful Reunion 'Reality Club'  | 8.7
# Champagne Supernova'Oasis'          | 8.5
# Last Night On Earth 'Green Day'     | 8.4
# Painkiller 'Judas Priest'           | 7.8
# Malibu Nights 'LANY'                | 7.0
# Thinking About You 'Radiohead'      | 5.1
# Shunsine 'The Panturas'             | 1.0
